# %% [markdown]
# #Task1--Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or genders in a population.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path="C:\\Users\\seepa\\Datasets\\Population\\API_SP.POP.TOTL_DS2_en_csv_v2_900-checkpoint.csv"

# %%
# Load the dataset
data = pd.read_csv(file_path, skiprows=4)

# %%
# Display the first few rows of the dataset
data.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130072080.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...

# %%
# Display column names
data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', 'Unnamed: 68'],
#       dtype='object')

# %%
data.shape
# Out:
# (266, 69)

# %%
#Information about the dataset
data.info
# Out:
# <bound method DataFrame.info of                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54922.0      55578.0      56320.0      57002.0
# ...

# %%
# Create a bar chart
plt.figure(figsize=(12, 6))
plt.bar(population_data["Country Name"], population_data[year], color='skyblue')
plt.xlabel("Country")
plt.ylabel("Population")
plt.title(f"Population Distribution by Country ({year})")
plt.xticks(rotation=45, ha='right')  # Rotate country names for readability
plt.tight_layout()
plt.show()

# %%
# Filter data for India
india_data = data[data["Country Name"] == "India"]
# Drop irrelevant columns
india_population = india_data.drop(["Country Name", "Country Code", "Indicator Name", "Indicator Code"], axis=1).transpose()
# Rename the column for clarity
india_population.columns = ["Population"]
india_population.index.name = "Year"

# Reset the index for better visualization
india_population.reset_index(inplace=True)
india_population = india_population.rename(columns={"index": "Year"})

# %%
# Plot India's population over time
plt.figure(figsize=(12, 6))
plt.plot(india_population["Year"], india_population["Population"], marker='o', linestyle='-', color='blue')
plt.xlabel("Year")
plt.ylabel("Population")
plt.title("Population of India Over Time")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
print(data.columns)
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', 'Unnamed: 68'],
#       dtype='object')

# %%
# Create a histogram of the population data
plt.figure(figsize=(10, 6))
plt.hist(population_data[year], bins=10, color='orange', edgecolor='black')
plt.xlabel("Population")
plt.ylabel("Frequency")
plt.title(f"Population Distribution Histogram ({year})")
plt.show()
